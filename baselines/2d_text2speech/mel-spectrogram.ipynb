# %%
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

# %%
def wav_to_mel_spectrogram(file_path, sr=None, n_fft=2048, hop_length=512, n_mels=128):
    # Load the .wav file
    y, sr = librosa.load(file_path, sr=sr)

    # Compute Mel-spectrogram
    mel_spectrogram = librosa.feature.melspectrogram(y=y, sr=sr, n_fft=n_fft, hop_length=hop_length, n_mels=n_mels)

    # Convert to log scale
    log_mel_spectrogram = librosa.power_to_db(mel_spectrogram)

    return log_mel_spectrogram

def display_mel_spectrogram(mel_spectrogram, sr, title, hop_length=512):
    plt.figure(figsize=(10, 4))
    librosa.display.specshow(mel_spectrogram, sr=sr, hop_length=hop_length, x_axis='time', y_axis='mel')
    plt.colorbar(format='%+2.0f dB')
    plt.xlim(0,2)
    plt.title(title)
    plt.tight_layout()
    plt.show()

def my_plot(file_path, title):
    mel_spectrogram = wav_to_mel_spectrogram(file_path)
    print(type(mel_spectrogram))
    sr = librosa.get_samplerate(file_path)
    display_mel_spectrogram(mel_spectrogram, sr, title)

# %% [markdown]
# # Plot Ground Truth Spectrogram

# %%
my_plot("./experiments_results/LJ013-0031.wav", title="Ground Truth")
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# # Plot Spectrogram without PE

# %%
my_plot("./experiments_results/wav_without_PE.wav", "Without PE")
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# # Plot Spectrogram with PE

# %%
my_plot(
    "./experiments_results/wav_with_PE.wav",
    "With PE",
)
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# # Plot Spectrogram with SPE

# %%
my_plot(
    "./experiments_results/wav_with_SPE.wav",
    "With SPE",
)
# Out:
# <class 'numpy.ndarray'>
